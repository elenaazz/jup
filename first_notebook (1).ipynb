# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Elena__  <br>
# Newly graduated student

# %% [markdown]
# _I'm interested in Data Science because it is a field that has always fascinated me and I would like to find an occupation related to it._

# %% [markdown]
# ### The code in cell five. It is supposed to print the result of an addition operation

# %%
x = 5 + 9


print('The result of the addition is', x)
# Out:
# The result of the addition is 14

# %% [markdown]
# <a href="https://waldyrious.net/viridis-palette-generator/">Viridis Palette Generator</a> <hr>
#
# |col1 | col2 | col3| col4|
# | ----| ---- | ----| ----|
# |row2 | ---- |  ---| ----
